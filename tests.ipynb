# %% [markdown]
# # Connect 4

# %%
from games import Connect4
from players import Connect4AI

ai = Connect4AI(
    'AI', 
    verbose=True, 
    max_depth=float('inf')
)

# %%
game = Connect4()
turns = [3, 3, 3, 3, 3, 0, 1, 1, 5, 4, 4, 4, 4, 5, 6, 0, 1, 1, 5]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: 3 | Scored: -22
# Move: 4 | Scored: -22
# Move: 2 | Scored: -22
# Move: 5 | Scored: -22
# Move: 1 | Scored: -22
# Move: 6 | Scored: 5
# Move: 0 | Scored: -22

ai.choose_move(game)
# Out:
# Move: 3 | Scored: -22
# Move: 4 | Scored: -22
# Move: 2 | Scored: -22
# Move: 5 | Scored: -22
# Move: 1 | Scored: -22
# Move: 6 | Scored: 5
# Move: 0 | Scored: -22
# 6985 scenarios searched in 0.043153 seconds
# Cache hit rate: 14.03%
# 6

# %%
game = Connect4()
turns = [3, 3, 3, 3, 3, 0, 1, 1, 5, 4, 4, 4, 4, 5, 6, 0, 1, 1]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: 3 | Scored: -5
# Move: 4 | Scored: 8
# Move: 2 | Scored: -23
# Move: 5 | Scored: -5
# Move: 1 | Scored: -5
# Move: 6 | Scored: -5
# Move: 0 | Scored: -5

ai.choose_move(game)
# Out:
# Move: 3 | Scored: -5
# Move: 4 | Scored: 8
# Move: 2 | Scored: -23
# Move: 5 | Scored: -5
# Move: 1 | Scored: -5
# Move: 6 | Scored: -5
# Move: 0 | Scored: -5
# 45153 scenarios searched in 0.296095 seconds
# Cache hit rate: 15.85%
# 4

# %%
game = Connect4()
turns = [3, 3, 3, 3, 3, 0, 1, 1, 5, 4, 4, 4, 4, 5, 6]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: 3 | Scored: -2
# Move: 4 | Scored: 0
# Move: 2 | Scored: -26
# Move: 5 | Scored: 0
# Move: 1 | Scored: -8
# Move: 6 | Scored: -2
# Move: 0 | Scored: -8

ai.choose_move(game)
# Out:
# Move: 3 | Scored: -2
# Move: 4 | Scored: 0
# Move: 2 | Scored: -26
# Move: 5 | Scored: 0
# Move: 1 | Scored: -8
# Move: 6 | Scored: -2
# Move: 0 | Scored: -8
# 1444161 scenarios searched in 11.129811 seconds
# Cache hit rate: 27.41%
# 4

# %%
game = Connect4()
turns = [3, 3, 3, 3, 3, 0, 1, 1, 5, 4, 4, 4, 4]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: 3 | Scored: -2
# Move: 4 | Scored: 0
# Move: 2 | Scored: -28
# Move: 5 | Scored: 0
# Move: 1 | Scored: -8
# Move: 6 | Scored: 0
# Move: 0 | Scored: -8

ai.choose_move(game)
# Out:
# Move: 3 | Scored: -2
# Move: 4 | Scored: 0
# Move: 2 | Scored: -28
# Move: 5 | Scored: 0
# Move: 1 | Scored: -8
# Move: 6 | Scored: 0
# Move: 0 | Scored: -8
# 3111787 scenarios searched in 25.576107 seconds
# Cache hit rate: 29.58%
# 4

# %%
game = Connect4()
turns = [3, 3, 3, 3, 3, 3, 4, 2, 4, 4, 5, 6, 5, 4, 4, 2, 4, 6, 6, 6, 6, 6, 1, 1, 1]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: 2 | Scored: -16
# Move: 5 | Scored: 7
# Move: 1 | Scored: 13
# Move: 0 | Scored: 15

ai.choose_move(game)
# Out:
# Move: 2 | Scored: -16
# Move: 5 | Scored: 7
# Move: 1 | Scored: 13
# Move: 0 | Scored: 15
# 218 scenarios searched in 0.001272 seconds
# Cache hit rate: 10.09%
# 0

# %%
game = Connect4()
turns = [3, 3, 3, 3, 3, 3, 4, 2, 4, 4, 5, 6, 5, 4, 4, 2, 4, 6, 6, 6, 6, 6, 1, 1, 1, 0, 0]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: 2 | Scored: 15
# Move: 5 | Scored: 13
# Move: 1 | Scored: 13
# Move: 0 | Scored: 5

ai.choose_move(game)
# Out:
# Move: 2 | Scored: 15
# Move: 5 | Scored: 13
# Move: 1 | Scored: 13
# Move: 0 | Scored: 5
# 186 scenarios searched in 0.001286 seconds
# Cache hit rate: 6.45%
# 2

# %% [markdown]
# # Dominoes

# %%
from games import Dominoes
from players import DominoesAI

ai = DominoesAI(
    'AI', 
    verbose=True, 
    max_depth=float('inf')
)

# %%
test_tiles = [
    {(0, 4), (1, 4), (2, 3), (3, 5), (3, 6), (4, 6), (5, 5)},
    {(0, 3), (1, 1), (1, 2), (1, 3), (1, 6), (2, 5), (2, 6)},
    {(0, 0), (0, 5), (0, 6), (3, 4), (4, 4), (4, 5), (5, 6)},
    {(0, 1), (0, 2), (1, 5), (2, 2), (2, 4), (3, 3), (6, 6)}
]

game = Dominoes(
    single_player=False, 
    tiles=test_tiles
)

## Expected output:
# Move: 15 | Scored: -16
# Move: 26 | Scored: 9
# Move: 5 | Scored: 6
# Move: 22 | Scored: -23
# Move: 25 | Scored: -17
# Move: 21 | Scored: 0
# Move: 11 | Scored: -28

ai.choose_move(game)
# Out:
# All tiles:  {(2, 3), (5, 5), (0, 4), (3, 6), (4, 6), (3, 5), (1, 4)}
#
# Available tiles:
# 15: (2, 3)
# 26: (5, 5)
# 5: (0, 4)
# 22: (3, 6)
# 25: (4, 6)
# 21: (3, 5)
# 11: (1, 4)
#
# Move: 15 | Scored: -16
# Move: 26 | Scored: 9
# Move: 5 | Scored: 6
# Move: 22 | Scored: -23
# Move: 25 | Scored: -17
# Move: 21 | Scored: 0
# Move: 11 | Scored: -28
# 1628063 scenarios searched in 14.819967 seconds
# Cache hit rate: 24.16%
# 26

# %%
from runner import play

test_tiles = [
    {(0, 4), (1, 4), (2, 3), (3, 5), (3, 6), (4, 6), (5, 5)},
    {(0, 3), (1, 1), (1, 2), (1, 3), (1, 6), (2, 5), (2, 6)},
    {(0, 0), (0, 5), (0, 6), (3, 4), (4, 4), (4, 5), (5, 6)},
    {(0, 1), (0, 2), (1, 5), (2, 2), (2, 4), (3, 3), (6, 6)}
]

game = Dominoes(
    single_player=False, 
    tiles=test_tiles
)

play(game, ai, ai)
# Out:
#  --------------------------------------------------
#  []
#
# Turn: AI 0 - Team 0
# All tiles:  {(2, 3), (5, 5), (0, 4), (3, 6), (4, 6), (3, 5), (1, 4)}
#
# Available tiles:
# 15: (2, 3)
# 26: (5, 5)
# 5: (0, 4)
# 22: (3, 6)
# 25: (4, 6)
# 21: (3, 5)
# 11: (1, 4)
#
# Move: 15 | Scored: -16
# Move: 26 | Scored: 9
# Move: 5 | Scored: 6
# Move: 22 | Scored: -23
# Move: 25 | Scored: -17
# Move: 21 | Scored: 0
# Move: 11 | Scored: -28
# 43 scenarios searched in 0.000481 seconds
# Cache hit rate: 83.72%
# AI 0 - Team 0 plays: 26
#
#
#  --------------------------------------------------
#  [(5, 5)]
#
# Turn: AI 1 - Team 1
# All tiles:  {(1, 2), (2, 6), (2, 5), (1, 6), (1, 1), (0, 3), (1, 3)}
#
# Available tiles:
# -17: (2, 5)
# 17: (2, 5)
#
# Move: -17 | Scored: -9
# Move: 17 | Scored: -9
# 101084 scenarios searched in 1.610432 seconds
# Cache hit rate: 33.72%
# AI 1 - Team 1 plays: -17
#
#
#  --------------------------------------------------
#  [[2, 5], (5, 5)]
#
# Turn: AI 0 - Team 0
# ...

# %%
test_tiles = [
    {(0, 1), (1, 5), (2, 2), (2, 4), (4, 5), (5, 5), (6, 6)},
    {(0, 0), (0, 4), (1, 1), (1, 6), (2, 6), (3, 5), (5, 6)},
    {(0, 3), (1, 4), (2, 3), (3, 3), (3, 6), (4, 4), (4, 6)},
    {(0, 2), (0, 5), (0, 6), (1, 2), (1, 3), (2, 5), (3, 4)}
]

game = Dominoes(
    single_player=False, 
    tiles=test_tiles
)

## Expected output:
# Move: 2 | Scored: -33
# Move: 16 | Scored: -43
# Move: 26 | Scored: -21
# Move: 24 | Scored: -27
# Move: 14 | Scored: -35
# Move: 12 | Scored: -36
# Move: 28 | Scored: -28

ai.choose_move(game)
# Out:
# All tiles:  {(0, 1), (2, 4), (5, 5), (4, 5), (2, 2), (1, 5), (6, 6)}
#
# Available tiles:
# 2: (0, 1)
# 16: (2, 4)
# 26: (5, 5)
# 24: (4, 5)
# 14: (2, 2)
# 12: (1, 5)
# 28: (6, 6)
#
# Move: 2 | Scored: -33
# Move: 16 | Scored: -43
# Move: 26 | Scored: -21
# Move: 24 | Scored: -27
# Move: 14 | Scored: -35
# Move: 12 | Scored: -36
# Move: 28 | Scored: -28
# 1477573 scenarios searched in 15.583594 seconds
# Cache hit rate: 20.47%
# 26

# %%
test_tiles = [
    {(0, 1), (1, 5), (2, 2), (2, 4), (4, 5), (5, 5), (6, 6)},
    {(0, 0), (0, 4), (1, 1), (1, 6), (2, 6), (3, 5), (5, 6)},
    {(0, 3), (1, 4), (2, 3), (3, 3), (3, 6), (4, 4), (4, 6)},
    {(0, 2), (0, 5), (0, 6), (1, 2), (1, 3), (2, 5), (3, 4)}
]

game = Dominoes(
    single_player=False, 
    tiles=test_tiles
)

turns = [26, -27, -25, 17, 14, -5, -4, 3, 2, 8, 11, 20, 0, -21, 15, -6, 16, -1, 23, -7, -28]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: -18 | Scored: -11
# Move: -13 | Scored: 21

ai.choose_move(game)
# Out:
# All tiles:  {(2, 6), (1, 6)}
#
# Available tiles:
# -18: (2, 6)
# -13: (1, 6)
#
# Move: -18 | Scored: -11
# Move: -13 | Scored: 21
# 8 scenarios searched in 0.000069 seconds
# Cache hit rate: 87.50%
# -13

# %%
test_tiles = [
    {(4, 4), (3, 4), (1, 1), (2, 3), (0, 2), (3, 3), (5, 6)}, 
    {(0, 4), (1, 5), (4, 6), (0, 6), (4, 5), (0, 5), (2, 5)}, 
    {(1, 2), (2, 2), (0, 0), (2, 6), (3, 6), (6, 6), (3, 5)}, 
    {(0, 1), (2, 4), (5, 5), (0, 3), (1, 4), (1, 6), (1, 3)}
]

game = Dominoes(
    single_player=False, 
    tiles=test_tiles
)

turns = [15, -17, -21, -10, 19, -12, 22, 13, -27, -25, 9, 16, -23, -24, 0, 11, 8, -6, -1]#, -4, -20, -5, 0, 2, -3]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: -2 | Scored: 33
# Move: -4 | Scored: 26
# Move: 2 | Scored: -17

ai.choose_move(game)
# Out:
# All tiles:  {(0, 1), (5, 5), (0, 3)}
#
# Available tiles:
# -2: (0, 1)
# -4: (0, 3)
# 2: (0, 1)
#
# Move: -2 | Scored: 33
# Move: -4 | Scored: 26
# Move: 2 | Scored: -17
# 21 scenarios searched in 0.000135 seconds
# Cache hit rate: 0.00%
# -2
