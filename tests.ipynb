# %% [markdown]
# # Connect 4

# %%
from game.board_games import Connect4, Connect4Player, Connect4AI

ai = Connect4AI(
    'AI', 
    verbose=True, 
    max_depth=float('inf')
)

# %%
game = Connect4()
turns = [3, 3, 3, 3, 3, 0, 1, 1, 5, 4, 4, 4, 4, 5, 6, 0, 1, 1, 5]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: 3 | Scored: -22
# Move: 4 | Scored: -22
# Move: 2 | Scored: -22
# Move: 5 | Scored: -22
# Move: 1 | Scored: -22
# Move: 6 | Scored: 5
# Move: 0 | Scored: -22

ai(game)
# Out:
# Move: 3 | Scored: -22
# Move: 4 | Scored: -22
# Move: 2 | Scored: -22
# Move: 5 | Scored: -22
# Move: 1 | Scored: -22
# Move: 6 | Scored: 5
# Move: 0 | Scored: -22
# 7031 scenarios searched in 0.043228 seconds
# Cache hit rate: 13.92%
# 6

# %%
game = Connect4()
turns = [3, 3, 3, 3, 3, 0, 1, 1, 5, 4, 4, 4, 4, 5, 6, 0, 1, 1]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: 3 | Scored: -5
# Move: 4 | Scored: 8
# Move: 2 | Scored: -23
# Move: 5 | Scored: -5
# Move: 1 | Scored: -5
# Move: 6 | Scored: -5
# Move: 0 | Scored: -5

ai(game)
# Out:
# Move: 3 | Scored: -5
# Move: 4 | Scored: 8
# Move: 2 | Scored: -23
# Move: 5 | Scored: -5
# Move: 1 | Scored: -5
# Move: 6 | Scored: -5
# Move: 0 | Scored: -5
# 45918 scenarios searched in 0.253855 seconds
# Cache hit rate: 15.74%
# 4

# %%
game = Connect4()
turns = [3, 3, 3, 3, 3, 0, 1, 1, 5, 4, 4, 4, 4, 5, 6]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: 3 | Scored: -2
# Move: 4 | Scored: 0
# Move: 2 | Scored: -26
# Move: 5 | Scored: 0
# Move: 1 | Scored: -8
# Move: 6 | Scored: -2
# Move: 0 | Scored: -8

ai(game)
# Out:
# Move: 3 | Scored: -2
# Move: 4 | Scored: 0
# Move: 2 | Scored: -26
# Move: 5 | Scored: 0
# Move: 1 | Scored: -8
# Move: 6 | Scored: -2
# Move: 0 | Scored: -8
# 1532166 scenarios searched in 11.232534 seconds
# Cache hit rate: 27.33%
# 4

# %%
game = Connect4()
turns = [3, 3, 3, 3, 3, 0, 1, 1, 5, 4, 4, 4, 4]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: 3 | Scored: -2
# Move: 4 | Scored: 0
# Move: 2 | Scored: -28
# Move: 5 | Scored: 0
# Move: 1 | Scored: -8
# Move: 6 | Scored: 0
# Move: 0 | Scored: -8

ai(game)
# Out:
# Move: 3 | Scored: -2
# Move: 4 | Scored: 0
# Move: 2 | Scored: -28
# Move: 5 | Scored: 0
# Move: 1 | Scored: -8
# Move: 6 | Scored: 0
# Move: 0 | Scored: -8
# 3351850 scenarios searched in 23.954107 seconds
# Cache hit rate: 29.43%
# 4

# %%
game = Connect4()
turns = [3, 3, 3, 3, 3, 3, 4, 2, 4, 4, 5, 6, 5, 4, 4, 2, 4, 6, 6, 6, 6, 6, 1, 1, 1]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: 2 | Scored: -16
# Move: 5 | Scored: 7
# Move: 1 | Scored: 13
# Move: 0 | Scored: 15

ai(game)
# Out:
# Move: 2 | Scored: -16
# Move: 5 | Scored: 7
# Move: 1 | Scored: 13
# Move: 0 | Scored: 15
# 218 scenarios searched in 0.001227 seconds
# Cache hit rate: 9.63%
# 0

# %%
game = Connect4()
turns = [3, 3, 3, 3, 3, 3, 4, 2, 4, 4, 5, 6, 5, 4, 4, 2, 4, 6, 6, 6, 6, 6, 1, 1, 1, 0, 0]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: 2 | Scored: 15
# Move: 5 | Scored: 13
# Move: 1 | Scored: 13
# Move: 0 | Scored: 5

ai(game)
# Out:
# Move: 2 | Scored: 15
# Move: 5 | Scored: 13
# Move: 1 | Scored: 13
# Move: 0 | Scored: 5
# 186 scenarios searched in 0.000983 seconds
# Cache hit rate: 6.45%
# 2

# %% [markdown]
# # Dominoes

# %%
from game.board_games import Dominoes, DominoesPlayer, DominoesAI

ai = DominoesAI(
    'AI', 
    verbose=True, 
    max_depth=float('inf')
)

# %%
test_tiles = [
    {(0, 4), (1, 4), (2, 3), (3, 5), (3, 6), (4, 6), (5, 5)},
    {(0, 3), (1, 1), (1, 2), (1, 3), (1, 6), (2, 5), (2, 6)},
    {(0, 0), (0, 5), (0, 6), (3, 4), (4, 4), (4, 5), (5, 6)},
    {(0, 1), (0, 2), (1, 5), (2, 2), (2, 4), (3, 3), (6, 6)}
]

game = Dominoes(
    single_player=False, 
    tiles=test_tiles
)

## Expected output:
# Move: 15 | Scored: -16
# Move: 26 | Scored: 9
# Move: 5 | Scored: 6
# Move: 22 | Scored: -23
# Move: 25 | Scored: -17
# Move: 21 | Scored: 0
# Move: 11 | Scored: -28

ai(game)
# Out:
# All tiles:  {(2, 3), (5, 5), (0, 4), (3, 6), (4, 6), (3, 5), (1, 4)}
#
# Available tiles:
# 15: (2, 3)
# 26: (5, 5)
# 5: (0, 4)
# 22: (3, 6)
# 25: (4, 6)
# 21: (3, 5)
# 11: (1, 4)
#
# Move: 15 | Scored: -16
# Move: 26 | Scored: 9
# Move: 5 | Scored: 6
# Move: 22 | Scored: -23
# Move: 25 | Scored: -17
# Move: 21 | Scored: 0
# Move: 11 | Scored: -28
# 1659289 scenarios searched in 14.175113 seconds
# Cache hit rate: 22.58%
# 26

# %%
test_tiles = [
    {(0, 4), (1, 4), (2, 3), (3, 5), (3, 6), (4, 6), (5, 5)},
    {(0, 3), (1, 1), (1, 2), (1, 3), (1, 6), (2, 5), (2, 6)},
    {(0, 0), (0, 5), (0, 6), (3, 4), (4, 4), (4, 5), (5, 6)},
    {(0, 1), (0, 2), (1, 5), (2, 2), (2, 4), (3, 3), (6, 6)}
]

game = Dominoes(
    single_player=False, 
    tiles=test_tiles
)

game.play(ai, ai)
# Out:
#  --------------------------------------------------
#  []
#
# Turn: AI 0 - Team 0
# All tiles:  {(2, 3), (5, 5), (0, 4), (3, 6), (4, 6), (3, 5), (1, 4)}
#
# Available tiles:
# 15: (2, 3)
# 26: (5, 5)
# 5: (0, 4)
# 22: (3, 6)
# 25: (4, 6)
# 21: (3, 5)
# 11: (1, 4)
#
# Move: 15 | Scored: -16
# Move: 26 | Scored: 9
# Move: 5 | Scored: 6
# Move: 22 | Scored: -23
# Move: 25 | Scored: -17
# Move: 21 | Scored: 0
# Move: 11 | Scored: -28
# 43 scenarios searched in 0.000490 seconds
# Cache hit rate: 83.72%
# AI 0 - Team 0 plays: 26
#
#
#  --------------------------------------------------
#  [(5, 5)]
#
# Turn: AI 1 - Team 1
# All tiles:  {(1, 2), (2, 6), (2, 5), (1, 6), (1, 1), (0, 3), (1, 3)}
#
# Available tiles:
# -17: (2, 5)
# 17: (2, 5)
#
# Move: -17 | Scored: -9
# Move: 17 | Scored: -9
# 104918 scenarios searched in 1.453005 seconds
# Cache hit rate: 31.10%
# AI 1 - Team 1 plays: -17
#
#
#  --------------------------------------------------
#  [[2, 5], (5, 5)]
#
# Turn: AI 2 - Team 0
# All tiles:  {(4, 4), (3, 4), (0, 0), (0, 6), (4, 5), (0, 5), (5, 6)}
#
# Available tiles:
# 24: (4, 5)
# 6: (0, 5)
# 27: (5, 6)
#
# Move: 24 | Scored: 9
# Move: 6 | Scored: 8
# Move: 27 | Scored: 9
# 57352 scenarios searched in 0.390104 seconds
# Cache hit rate: 36.61%
# AI 2 - Team 0 plays: 24
#
#
#  --------------------------------------------------
#  [[2, 5], (5, 5), [5, 4]]
#
# Turn: AI 3 - Team 1
# All tiles:  {(0, 1), (2, 4), (1, 5), (3, 3), (0, 2), (2, 2), (6, 6)}
#
# Available tiles:
# -16: (2, 4)
# -3: (0, 2)
# -14: (2, 2)
# 16: (2, 4)
#
# Move: -16 | Scored: -17
# Move: -3 | Scored: -30
# Move: -14 | Scored: -9
# Move: 16 | Scored: -16
# 9380 scenarios searched in 0.068214 seconds
# Cache hit rate: 39.41%
# AI 3 - Team 1 plays: -14
#
#
#  --------------------------------------------------
#  [[2, 2], [2, 5], (5, 5), [5, 4]]
#
# Turn: AI 0 - Team 0
# All tiles:  {(2, 3), (4, 6), (0, 4), (3, 6), (3, 5), (1, 4)}
#
# Available tiles:
# -15: (2, 3)
# 25: (4, 6)
# 5: (0, 4)
# 11: (1, 4)
#
# Move: -15 | Scored: 9
# Move: 25 | Scored: 8
# Move: 5 | Scored: -18
# Move: 11 | Scored: -44
# 19760 scenarios searched in 0.137691 seconds
# Cache hit rate: 32.49%
# AI 0 - Team 0 plays: -15
#
#
#  --------------------------------------------------
#  [[3, 2], [2, 2], [2, 5], (5, 5), [5, 4]]
#
# Turn: AI 1 - Team 1
# All tiles:  {(1, 2), (0, 3), (1, 1), (2, 6), (1, 6), (1, 3)}
#
# Available tiles:
# -4: (0, 3)
# -10: (1, 3)
#
# Move: -4 | Scored: -11
# Move: -10 | Scored: -9
# 2589 scenarios searched in 0.018110 seconds
# Cache hit rate: 39.17%
# AI 1 - Team 1 plays: -10
#
#
#  --------------------------------------------------
#  [[1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4]]
#
# Turn: AI 2 - Team 0
# All tiles:  {(4, 4), (3, 4), (0, 0), (0, 6), (0, 5), (5, 6)}
#
# Available tiles:
# 23: (4, 4)
# 20: (3, 4)
#
# Move: 23 | Scored: 9
# Move: 20 | Scored: 8
# 5738 scenarios searched in 0.039119 seconds
# Cache hit rate: 44.30%
# AI 2 - Team 0 plays: 23
#
#
#  --------------------------------------------------
#  [[1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4]]
#
# Turn: AI 3 - Team 1
# All tiles:  {(0, 1), (2, 4), (1, 5), (3, 3), (0, 2), (6, 6)}
#
# Available tiles:
# -2: (0, 1)
# -12: (1, 5)
# 16: (2, 4)
#
# Move: -2 | Scored: -34
# Move: -12 | Scored: -16
# Move: 16 | Scored: -9
# 16 scenarios searched in 0.000149 seconds
# Cache hit rate: 81.25%
# AI 3 - Team 1 plays: 16
#
#
#  --------------------------------------------------
#  [[1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2]]
#
# Turn: AI 0 - Team 0
# All tiles:  {(4, 6), (0, 4), (3, 6), (3, 5), (1, 4)}
#
# Available tiles:
# -11: (1, 4)
#
# Move: -11 | Scored: 9
# 5 scenarios searched in 0.000040 seconds
# Cache hit rate: 80.00%
# AI 0 - Team 0 plays: -11
#
#
#  --------------------------------------------------
#  [[4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2]]
#
# Turn: AI 1 - Team 1
# All tiles:  {(1, 2), (1, 1), (0, 3), (2, 6), (1, 6)}
#
# Available tiles:
# 9: (1, 2)
# 18: (2, 6)
#
# Move: 9 | Scored: -9
# Move: 18 | Scored: -21
# 179 scenarios searched in 0.001314 seconds
# Cache hit rate: 58.66%
# AI 1 - Team 1 plays: 9
#
#
#  --------------------------------------------------
#  [[4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1]]
#
# Turn: AI 2 - Team 0
# All tiles:  {(3, 4), (0, 0), (0, 6), (5, 6), (0, 5)}
#
# Available tiles:
# -20: (3, 4)
#
# Move: -20 | Scored: 9
# 6 scenarios searched in 0.000051 seconds
# Cache hit rate: 83.33%
# AI 2 - Team 0 plays: -20
#
#
#  --------------------------------------------------
#  [[3, 4], [4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1]]
#
# Turn: AI 3 - Team 1
# All tiles:  {(0, 1), (1, 5), (3, 3), (0, 2), (6, 6)}
#
# Available tiles:
# -19: (3, 3)
# 2: (0, 1)
# 12: (1, 5)
#
# Move: -19 | Scored: -9
# Move: 2 | Scored: -25
# Move: 12 | Scored: -26
# 413 scenarios searched in 0.002860 seconds
# Cache hit rate: 53.75%
# AI 3 - Team 1 plays: -19
#
#
#  --------------------------------------------------
#  [[3, 3], [3, 4], [4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1]]
#
# Turn: AI 0 - Team 0
# All tiles:  {(4, 6), (0, 4), (3, 6), (3, 5)}
#
# Available tiles:
# -22: (3, 6)
# -21: (3, 5)
#
# Move: -22 | Scored: -27
# Move: -21 | Scored: 9
# 32 scenarios searched in 0.000256 seconds
# Cache hit rate: 93.75%
# AI 0 - Team 0 plays: -21
#
#
#  --------------------------------------------------
#  [[5, 3], [3, 3], [3, 4], [4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1]]
#
# Turn: AI 1 - Team 1
# All tiles:  {(0, 3), (1, 1), (2, 6), (1, 6)}
#
# Available tiles:
# 8: (1, 1)
# 13: (1, 6)
#
# Move: 8 | Scored: -9
# Move: 13 | Scored: -9
# 117 scenarios searched in 0.000867 seconds
# Cache hit rate: 42.74%
# AI 1 - Team 1 plays: 8
#
#
#  --------------------------------------------------
#  [[5, 3], [3, 3], [3, 4], [4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1], [1, 1]]
#
# Turn: AI 2 - Team 0
# All tiles:  {(0, 0), (0, 6), (0, 5), (5, 6)}
#
# Available tiles:
# -6: (0, 5)
# -27: (5, 6)
#
# Move: -6 | Scored: -23
# Move: -27 | Scored: 9
# 13 scenarios searched in 0.000094 seconds
# Cache hit rate: 84.62%
# AI 2 - Team 0 plays: -27
#
#
#  --------------------------------------------------
#  [[6, 5], [5, 3], [3, 3], [3, 4], [4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1], [1, 1]]
#
# Turn: AI 3 - Team 1
# All tiles:  {(0, 1), (1, 5), (0, 2), (6, 6)}
#
# Available tiles:
# -28: (6, 6)
# 2: (0, 1)
# 12: (1, 5)
#
# Move: -28 | Scored: -9
# Move: 2 | Scored: -33
# Move: 12 | Scored: -30
# 75 scenarios searched in 0.000474 seconds
# Cache hit rate: 65.33%
# AI 3 - Team 1 plays: -28
#
#
#  --------------------------------------------------
#  [[6, 6], [6, 5], [5, 3], [3, 3], [3, 4], [4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1], [1, 1]]
#
# Turn: AI 0 - Team 0
# All tiles:  {(4, 6), (0, 4), (3, 6)}
#
# Available tiles:
# -25: (4, 6)
# -22: (3, 6)
#
# Move: -25 | Scored: 9
# Move: -22 | Scored: -14
# 30 scenarios searched in 0.000179 seconds
# Cache hit rate: 53.33%
# AI 0 - Team 0 plays: -25
#
#
#  --------------------------------------------------
#  [[4, 6], [6, 6], [6, 5], [5, 3], [3, 3], [3, 4], [4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1], [1, 1]]
#
# Turn: AI 1 - Team 1
# All tiles:  {(0, 3), (2, 6), (1, 6)}
#
# Available tiles:
# 13: (1, 6)
#
# Move: 13 | Scored: -9
# 6 scenarios searched in 0.000037 seconds
# Cache hit rate: 83.33%
# AI 1 - Team 1 plays: 13
#
#
#  --------------------------------------------------
#  [[4, 6], [6, 6], [6, 5], [5, 3], [3, 3], [3, 4], [4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1], [1, 1], [1, 6]]
#
# Turn: AI 2 - Team 0
# All tiles:  {(0, 0), (0, 6), (0, 5)}
#
# Available tiles:
# 7: (0, 6)
#
# Move: 7 | Scored: 9
# 11 scenarios searched in 0.000066 seconds
# Cache hit rate: 81.82%
# AI 2 - Team 0 plays: 7
#
#
#  --------------------------------------------------
#  [[4, 6], [6, 6], [6, 5], [5, 3], [3, 3], [3, 4], [4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1], [1, 1], [1, 6], [6, 0]]
#
# Turn: AI 3 - Team 1
# All tiles:  {(0, 1), (1, 5), (0, 2)}
#
# Available tiles:
# 2: (0, 1)
# 3: (0, 2)
#
# Move: 2 | Scored: -10
# Move: 3 | Scored: -9
# 12 scenarios searched in 0.000066 seconds
# Cache hit rate: 75.00%
# AI 3 - Team 1 plays: 3
#
#
#  --------------------------------------------------
#  [[4, 6], [6, 6], [6, 5], [5, 3], [3, 3], [3, 4], [4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1], [1, 1], [1, 6], [6, 0], [0, 2]]
#
# Turn: AI 0 - Team 0
# All tiles:  {(0, 4), (3, 6)}
#
# Available tiles:
# -5: (0, 4)
#
# Move: -5 | Scored: 9
# 7 scenarios searched in 0.000041 seconds
# Cache hit rate: 71.43%
# AI 0 - Team 0 plays: -5
#
#
#  --------------------------------------------------
#  [[0, 4], [4, 6], [6, 6], [6, 5], [5, 3], [3, 3], [3, 4], [4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1], [1, 1], [1, 6], [6, 0], [0, 2]]
#
# Turn: AI 1 - Team 1
# All tiles:  {(0, 3), (2, 6)}
#
# Available tiles:
# -4: (0, 3)
# 18: (2, 6)
#
# Move: -4 | Scored: -15
# Move: 18 | Scored: -9
# 6 scenarios searched in 0.000033 seconds
# Cache hit rate: 50.00%
# AI 1 - Team 1 plays: 18
#
#
#  --------------------------------------------------
#  [[0, 4], [4, 6], [6, 6], [6, 5], [5, 3], [3, 3], [3, 4], [4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1], [1, 1], [1, 6], [6, 0], [0, 2], [2, 6]]
#
# Turn: AI 2 - Team 0
# All tiles:  {(0, 0), (0, 5)}
#
# Available tiles:
# -1: (0, 0)
# -6: (0, 5)
#
# Move: -1 | Scored: 9
# Move: -6 | Scored: 4
# 6 scenarios searched in 0.000031 seconds
# Cache hit rate: 33.33%
# AI 2 - Team 0 plays: -1
#
#
#  --------------------------------------------------
#  [[0, 0], [0, 4], [4, 6], [6, 6], [6, 5], [5, 3], [3, 3], [3, 4], [4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1], [1, 1], [1, 6], [6, 0], [0, 2], [2, 6]]
#
# Turn: AI 3 - Team 1
# All tiles:  {(0, 1), (1, 5)}
#
# Available tiles:
# -2: (0, 1)
#
# Move: -2 | Scored: -9
# 2 scenarios searched in 0.000009 seconds
# Cache hit rate: 0.00%
# AI 3 - Team 1 plays: -2
#
#
#  --------------------------------------------------
#  [[1, 0], [0, 0], [0, 4], [4, 6], [6, 6], [6, 5], [5, 3], [3, 3], [3, 4], [4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1], [1, 1], [1, 6], [6, 0], [0, 2], [2, 6]]
#
# Turn: AI 0 - Team 0
# All tiles:  {(3, 6)}
#
# Available tiles:
# 22: (3, 6)
#
# Move: 22 | Scored: 9
# 2 scenarios searched in 0.000009 seconds
# Cache hit rate: 0.00%
# AI 0 - Team 0 plays: 22
#
#
#  --------------------------------------------------
#  [[1, 0], [0, 0], [0, 4], [4, 6], [6, 6], [6, 5], [5, 3], [3, 3], [3, 4], [4, 1], [1, 3], [3, 2], [2, 2], [2, 5], (5, 5), [5, 4], [4, 4], [4, 2], [2, 1], [1, 1], [1, 6], [6, 0], [0, 2], [2, 6], [6, 3]]
#
# Winner: AI 0 - Team 0
# Score: 9

# %%
test_tiles = [
    {(0, 1), (1, 5), (2, 2), (2, 4), (4, 5), (5, 5), (6, 6)},
    {(0, 0), (0, 4), (1, 1), (1, 6), (2, 6), (3, 5), (5, 6)},
    {(0, 3), (1, 4), (2, 3), (3, 3), (3, 6), (4, 4), (4, 6)},
    {(0, 2), (0, 5), (0, 6), (1, 2), (1, 3), (2, 5), (3, 4)}
]

game = Dominoes(
    single_player=False, 
    tiles=test_tiles
)

## Expected output:
# Move: 2 | Scored: -33
# Move: 16 | Scored: -43
# Move: 26 | Scored: -21
# Move: 24 | Scored: -27
# Move: 14 | Scored: -35
# Move: 12 | Scored: -36
# Move: 28 | Scored: -28

ai(game)
# Out:
# All tiles:  {(0, 1), (2, 4), (5, 5), (4, 5), (2, 2), (1, 5), (6, 6)}
#
# Available tiles:
# 2: (0, 1)
# 16: (2, 4)
# 26: (5, 5)
# 24: (4, 5)
# 14: (2, 2)
# 12: (1, 5)
# 28: (6, 6)
#
# Move: 2 | Scored: -33
# Move: 16 | Scored: -43
# Move: 26 | Scored: -21
# Move: 24 | Scored: -27
# Move: 14 | Scored: -35
# Move: 12 | Scored: -36
# Move: 28 | Scored: -28
# 1494555 scenarios searched in 12.354529 seconds
# Cache hit rate: 19.41%
# 26

# %%
test_tiles = [
    {(0, 1), (1, 5), (2, 2), (2, 4), (4, 5), (5, 5), (6, 6)},
    {(0, 0), (0, 4), (1, 1), (1, 6), (2, 6), (3, 5), (5, 6)},
    {(0, 3), (1, 4), (2, 3), (3, 3), (3, 6), (4, 4), (4, 6)},
    {(0, 2), (0, 5), (0, 6), (1, 2), (1, 3), (2, 5), (3, 4)}
]

game = Dominoes(
    single_player=False, 
    tiles=test_tiles
)

turns = [26, -27, -25, 17, 14, -5, -4, 3, 2, 8, 11, 20, 0, -21, 15, -6, 16, -1, 23, -7, -28]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: -18 | Scored: -11
# Move: -13 | Scored: 21

ai(game)
# Out:
# All tiles:  {(2, 6), (1, 6)}
#
# Available tiles:
# -18: (2, 6)
# -13: (1, 6)
#
# Move: -18 | Scored: -11
# Move: -13 | Scored: 21
# 11 scenarios searched in 0.000086 seconds
# Cache hit rate: 72.73%
# -13

# %%
test_tiles = [
    {(4, 4), (3, 4), (1, 1), (2, 3), (0, 2), (3, 3), (5, 6)}, 
    {(0, 4), (1, 5), (4, 6), (0, 6), (4, 5), (0, 5), (2, 5)}, 
    {(1, 2), (2, 2), (0, 0), (2, 6), (3, 6), (6, 6), (3, 5)}, 
    {(0, 1), (2, 4), (5, 5), (0, 3), (1, 4), (1, 6), (1, 3)}
]

game = Dominoes(
    single_player=False, 
    tiles=test_tiles
)

turns = [15, -17, -21, -10, 19, -12, 22, 13, -27, -25, 9, 16, -23, -24, 0, 11, 8, -6, -1]#, -4, -20, -5, 0, 2, -3]

for turn in turns:
    game.play_move(turn)

## Expected output:
# Move: -2 | Scored: 33
# Move: -4 | Scored: 26
# Move: 2 | Scored: -17

ai(game)
# Out:
# All tiles:  {(0, 1), (5, 5), (0, 3)}
#
# Available tiles:
# -2: (0, 1)
# -4: (0, 3)
# 2: (0, 1)
#
# Move: -2 | Scored: 33
# Move: -4 | Scored: 26
# Move: 2 | Scored: -17
# 21 scenarios searched in 0.000141 seconds
# Cache hit rate: 0.00%
# -2
